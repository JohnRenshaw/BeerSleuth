# %%
# %run beer_munging.py

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='svg'
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter 
from IPython.display import Image

# %%
print("there are %d unique beer syles in the data set ")%len(ratings_df.style.unique())
# Out:
# there are 257 unique beer syles in the data set

# %%
style_counts = Counter(beer_df.style)

# %%
label = [x[0] for x in style_counts.most_common(20)]
y = [x[1] for x in style_counts.most_common(20)]

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=label, y=y, palette="GnBu_d")
plt.xticks(rotation=25, ha='right')
plt.title('Top 20 Beer Styles')
plt.ylabel('Count')

# %%
reviews_per_beer = Counter(ratings_df['beer'])
reviews_per_user = Counter(ratings_df['user'])

# %%
fig, ax = plt.subplots(2, figsize = (10,7))
ax[0].hist(reviews_per_beer.values(), range = (0,200), bins = 200, log=True)
ax[0].set_ylabel('log(count)')
ax[0].set_xlabel('reviews per beer')
ax[1].hist(reviews_per_user.values(), range = (0,200), bins = 200, log=True, color = "green")
ax[1].set_ylabel('log(count)')
ax[1].set_xlabel('reviews per user')
